# %% [markdown]
# # Open CV face detection

# %%
import cv2

# %%
faceCascade=cv2.CascadeClassifier(r"C:\Users\user\.conda\envs\dark\reconn\haarcascade_frontalcatface.xml")

# %%
image=cv2.imread(r"C:\Users\user\.conda\envs\dark\reconn\3cats.jpg")

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(image)

# %%
    RGB_img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    plt.imshow(RGB_img)

# %%
GR_img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
plt.imshow(GR_img)

# %%
faces=faceCascade.detectMultiScale(
    GR_img,
    scaleFactor=1.0001,
    minNeighbors=5,
    minSize=(50,50)
    
)
print(faces)
# Out:
# [[ 36  34  61  61]
#  [203  51  55  55]
#  [114  53  59  59]
#  [ 12  73  50  50]
#  [101  18 143 143]]

# %%
image=cv2.imread(r"C:\Users\user\.conda\envs\dark\reconn\3cats.jpg")

# %%
for(x,y,w,h) in faces:
    cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)
RGB_img=cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)

# %% [markdown]
# ## Extra : Crop faces

# %%
ims=[]
for(x,y,w,h) in faces:
    crop=RGB_img[y:y+h,x:x+w]
    ims.append(crop)

# %%
plt.imshow(ims[1])

# %%
plt.imshow(ims[2])

# %%
plt.imshow(ims[0])
